# %% [markdown]
# # First Implementation of a flow matching model
# - do we need classifier free guidance? -> i think no

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import hydra

from genpp import BASE_DIR
from genpp.configs import register_resolvers

register_resolvers()

# %%
with hydra.initialize_config_dir(version_base=None, config_dir=str(BASE_DIR / "configs")):
    cfg = hydra.compose(config_name="base_fmunet")
datamodule = hydra.utils.instantiate(cfg.data.module)
# Right now this is a large model
model = hydra.utils.instantiate(cfg.model)

# %%
datamodule.prepare_data()
datamodule.setup(stage="fit")
dl = datamodule.train_dataloader()

# %%
for batch in dl:
    y, x_1 = batch  # y is now out conditioning variable and x_1 is the "target"
    break
# Out:
# /Users/moritzfeik/Developer/GENPP/.pixi/envs/dev/lib/python3.13/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
y.shape
# Out:
# torch.Size([8, 63, 40, 32])

# %%
x_1.shape
# Out:
# torch.Size([8, 2, 40, 32])

# %%
model.training_step(batch, 0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.training_step(batch, 0)
#
# File ~/Developer/GENPP/src/genpp/models/fm/fm_cnn.py:426, in FMUNet.training_step(self, batch, batch_idx)
#     425 def training_step(self, batch, batch_idx) -> torch.Tensor:
# --> 426     loss = self._calc_loss(batch)
#     427     self.log(
#     428         "train_loss",
#     429         loss,
#    (...)    433         sync_dist=True,
#     434     )
#     435     return loss
#
# File ~/Developer/GENPP/src/genpp/models/fm/fm_cnn.py:419, in FMUNet._calc_loss(self, batch)
#     417 # Calc the l2 loss
#     418 t = rearrange(t, "b -> b 1 1 1")
# --> 419 u_t_theta = self.model(path_sample.x_t, path_sample.t, y)
#     420 u_t_ref = path_sample.dx_t
#     422 loss = torch.pow(u_t_theta - u_t_ref, 2).mean()
#
# File ~/Developer/GENPP/.pixi/envs/dev/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Developer/GENPP/.pixi/envs/dev/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Developer/GENPP/src/genpp/models/fm/fm_cnn.py:329, in _FMUNet.forward(self, x, t, y)
#     327 # Embed t and y
#     328 t_embed = self.time_embedder(t)  # [bs, time_embed_dim]
# --> 329 y_embed = self.y_embedder(y)  # [bs, c_y, 48, 32]
#     331 # Initial convolution
#     332 x = self.init_conv(x)  # [bs, c_0, 48, 32]
#
# File ~/Developer/GENPP/.pixi/envs/dev/lib/python3.13/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Developer/GENPP/.pixi/envs/dev/lib/python3.13/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Developer/GENPP/src/genpp/models/layers.py:245, in PixelEmbedder.forward(self, x)
#     243 emb = self.emb(pixel_idx)
#     244 emb = rearrange(emb, "b h w c -> b c h w")
# --> 245 x = torch.cat([x, self.emb(pixel_idx)], dim=1)
#     247 return x
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 40 but got size 32 for tensor number 1 in the list.
